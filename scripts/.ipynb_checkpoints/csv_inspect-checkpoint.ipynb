# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/peace/Documents/Github_Repos/DS_Traffic_Crash_Analytics_&_Safety_Intelligence_Platform/data/Traffic_CrashesData.csv")

# %%
df.head().T
# Out:
#                                                                                0  \
# CRASH_RECORD_ID                000c4307d8e9b39075cffdd0aade3603e0f96f14e41da9...
# CRASH_DATE                                                01/14/2025 12:25:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                           SNOW
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                        SIDESWIPE SAME DIRECTION
# TRAFFICWAY_TYPE                                  DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                               SNOW OR SLUSH
# ...

# %%
df.shape #660934, 39
# Out:
# (660934, 39)

# %%
columns = df.columns.to_list()
column_dtypes = df.dtypes.to_list()

# %%
for item in zip(columns, column_dtypes):
    print(item)
# Out:
# ('CRASH_RECORD_ID', dtype('O'))
# ('CRASH_DATE', dtype('O'))
# ('POSTED_SPEED_LIMIT', dtype('int64'))
# ('TRAFFIC_CONTROL_DEVICE', dtype('O'))
# ('DEVICE_CONDITION', dtype('O'))
# ('WEATHER_CONDITION', dtype('O'))
# ('LIGHTING_CONDITION', dtype('O'))
# ('FIRST_CRASH_TYPE', dtype('O'))
# ('TRAFFICWAY_TYPE', dtype('O'))
# ('ALIGNMENT', dtype('O'))
# ('ROADWAY_SURFACE_COND', dtype('O'))
# ('ROAD_DEFECT', dtype('O'))
# ('REPORT_TYPE', dtype('O'))
# ('CRASH_TYPE', dtype('O'))
# ('DAMAGE', dtype('O'))
# ('DATE_POLICE_NOTIFIED', dtype('O'))
# ('PRIM_CONTRIBUTORY_CAUSE', dtype('O'))
# ('SEC_CONTRIBUTORY_CAUSE', dtype('O'))
# ('STREET_NO', dtype('int64'))
# ('STREET_DIRECTION', dtype('O'))
# ('STREET_NAME', dtype('O'))
# ('BEAT_OF_OCCURRENCE', dtype('float64'))
# ('NUM_UNITS', dtype('int64'))
# ('MOST_SEVERE_INJURY', dtype('O'))
# ('INJURIES_TOTAL', dtype('float64'))
# ('INJURIES_FATAL', dtype('float64'))
# ('INJURIES_INCAPACITATING', dtype('float64'))
# ...

# %%
df.isnull().sum()
# Out:
# CRASH_RECORD_ID                  0
# CRASH_DATE                       0
# POSTED_SPEED_LIMIT               0
# TRAFFIC_CONTROL_DEVICE           0
# DEVICE_CONDITION                 0
# WEATHER_CONDITION                0
# LIGHTING_CONDITION               0
# FIRST_CRASH_TYPE                 0
# TRAFFICWAY_TYPE                  0
# ALIGNMENT                        0
# ROADWAY_SURFACE_COND             0
# ROAD_DEFECT                      0
# REPORT_TYPE                      0
# CRASH_TYPE                       0
# DAMAGE                           0
# DATE_POLICE_NOTIFIED             0
# PRIM_CONTRIBUTORY_CAUSE          0
# SEC_CONTRIBUTORY_CAUSE           0
# STREET_NO                        0
# STREET_DIRECTION                 0
# STREET_NAME                      0
# BEAT_OF_OCCURRENCE               0
# NUM_UNITS                        0
# MOST_SEVERE_INJURY               0
# INJURIES_TOTAL                   0
# INJURIES_FATAL                   0
# INJURIES_INCAPACITATING          0
# ...

# %%
df['CRASH_RECORD_ID'].astype(str).str.len().min() #min, max 128. soo all ids are 128 char long
# Out:
# 128

# %%
df.tail().T
# Out:
#                                                                           660929  \
# CRASH_RECORD_ID                5ff5b050ae2079df6addca8431c1bd6e381432ff72ff43...
# CRASH_DATE                                                10/18/2025 11:42:00 AM
# POSTED_SPEED_LIMIT                                                            35
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                CLOUDY/OVERCAST
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                        REAR END
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                     UNKNOWN
# ...

# %%
df[['CRASH_DATE','date']].head(10).T
# Out:
#                                  0                       1  \
# CRASH_DATE  01/14/2025 12:25:00 PM  05/23/2025 09:30:00 AM
# date           2025-01-14 12:25:00     2025-05-23 09:30:00
#
#                                  2                       3  \
# CRASH_DATE  04/05/2025 08:00:00 PM  05/23/2025 09:15:00 AM
# date           2025-04-05 20:00:00     2025-05-23 09:15:00
#
#                                  4                       5  \
# CRASH_DATE  01/14/2025 08:00:00 AM  01/14/2025 01:44:00 PM
# date           2025-01-14 08:00:00     2025-01-14 13:44:00
#
#                                  6                       7  \
# CRASH_DATE  03/16/2025 11:22:00 PM  12/04/2024 08:27:00 AM
# date           2025-03-16 23:22:00     2024-12-04 08:27:00
#
#                                  8                       9
# CRASH_DATE  10/05/2024 03:45:00 AM  09/07/2024 10:10:00 PM
# date           2024-10-05 03:45:00     2024-09-07 22:10:00

# %%
df['TRAFFIC_CONTROL_DEVICE'].astype(str).str.len().max() #max 24, min 5
# Out:
# 24

# %%
df['DEVICE_CONDITION'].astype(str).str.len().max() #max 24, min 5
# Out:
# 24

# %%
for col in columns:
    print(col,end=" ")
    print(df[col].astype(str).str.len().max())
# Out:
# CRASH_RECORD_ID 128
# CRASH_DATE 22
# POSTED_SPEED_LIMIT 2
# TRAFFIC_CONTROL_DEVICE 24
# DEVICE_CONDITION 24
# WEATHER_CONDITION 24
# LIGHTING_CONDITION 22
# FIRST_CRASH_TYPE 28
# TRAFFICWAY_TYPE 31
# ALIGNMENT 21
# ROADWAY_SURFACE_COND 15
# ROAD_DEFECT 17
# REPORT_TYPE 26
# CRASH_TYPE 32
# DAMAGE 13
# DATE_POLICE_NOTIFIED 22
# PRIM_CONTRIBUTORY_CAUSE 80
# SEC_CONTRIBUTORY_CAUSE 80
# STREET_NO 5
# STREET_DIRECTION 1
# STREET_NAME 27
# BEAT_OF_OCCURRENCE 6
# NUM_UNITS 2
# MOST_SEVERE_INJURY 24
# INJURIES_TOTAL 4
# INJURIES_FATAL 3
# INJURIES_INCAPACITATING 4
# INJURIES_NON_INCAPACITATING 4
# INJURIES_REPORTED_NOT_EVIDENT 4
# INJURIES_NO_INDICATION 4
# INJURIES_UNKNOWN 3
# CRASH_HOUR 2
# CRASH_DAY_OF_WEEK 1
# CRASH_MONTH 2
# LATITUDE 13
# LONGITUDE 14
# LOCATION 40
# date 19
# year 4

# %%
df.dtypes
# Out:
# CRASH_RECORD_ID                   object
# CRASH_DATE                        object
# POSTED_SPEED_LIMIT                 int64
# TRAFFIC_CONTROL_DEVICE            object
# DEVICE_CONDITION                  object
# WEATHER_CONDITION                 object
# LIGHTING_CONDITION                object
# FIRST_CRASH_TYPE                  object
# TRAFFICWAY_TYPE                   object
# ALIGNMENT                         object
# ROADWAY_SURFACE_COND              object
# ROAD_DEFECT                       object
# REPORT_TYPE                       object
# CRASH_TYPE                        object
# DAMAGE                            object
# DATE_POLICE_NOTIFIED              object
# PRIM_CONTRIBUTORY_CAUSE           object
# SEC_CONTRIBUTORY_CAUSE            object
# STREET_NO                          int64
# STREET_DIRECTION                  object
# STREET_NAME                       object
# BEAT_OF_OCCURRENCE               float64
# NUM_UNITS                          int64
# ...
